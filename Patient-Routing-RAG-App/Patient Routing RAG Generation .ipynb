# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: chromadb in c:\anaconda\lib\site-packages (from -r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: rich in c:\anaconda\lib\site-packages (from -r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: ollama in c:\anaconda\lib\site-packages (from -r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: faker in c:\anaconda\lib\site-packages (from -r requirements.txt (line 4)) (34.0.0)
# Requirement already satisfied: pandas in c:\anaconda\lib\site-packages (from -r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: fuzzywuzzy in c:\anaconda\lib\site-packages (from -r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: python-dotenv in c:\anaconda\lib\site-packages (from -r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: build>=1.0.3 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (2.10.5)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.115.7)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (3.11.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (32.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\anaconda\lib\site-packages (from chromadb->-r requirements.txt (line 1)) (0.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda\lib\site-packages (from rich->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda\lib\site-packages (from rich->-r requirements.txt (line 2)) (2.15.1)
# Requirement already satisfied: python-dateutil>=2.4 in c:\anaconda\lib\site-packages (from faker->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas->-r requirements.txt (line 5)) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\lib\site-packages (from pandas->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: packaging>=19.1 in c:\anaconda\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: pyproject_hooks in c:\anaconda\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\anaconda\lib\site-packages (from fastapi>=0.95.2->chromadb->-r requirements.txt (line 1)) (0.45.3)
# Requirement already satisfied: anyio in c:\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: certifi in c:\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 1)) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: idna in c:\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: sniffio in c:\anaconda\lib\site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (0.58.0)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: requests-oauthlib in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: durationpy>=0.7 in c:\anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (0.9)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: coloredlogs in c:\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (24.12.23)
# Requirement already satisfied: protobuf in c:\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (5.29.3)
# Requirement already satisfied: sympy in c:\anaconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\anaconda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 1)) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\anaconda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 1)) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in c:\anaconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 1)) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in c:\anaconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 1)) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\anaconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 1)) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in c:\anaconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 1)) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\anaconda\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\anaconda\lib\site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\anaconda\lib\site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 1)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\anaconda\lib\site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda\lib\site-packages (from pydantic>=1.9->chromadb->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\anaconda\lib\site-packages (from pydantic>=1.9->chromadb->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\anaconda\lib\site-packages (from tokenizers>=0.13.2->chromadb->-r requirements.txt (line 1)) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\anaconda\lib\site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\anaconda\lib\site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 1)) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 1)) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 1)) (14.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (4.9)
# Requirement already satisfied: filelock in c:\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 1)) (2024.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 1)) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: humanfriendly>=9.1 in c:\anaconda\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\anaconda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 1)) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 1)) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import json
import random
import requests
import psutil
import chromadb
from dotenv import load_dotenv

load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
url = "https://api.groq.com/openai/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {GROQ_API_KEY}",
    "Content-Type": "application/json"
}

client = chromadb.PersistentClient(path="chroma_db_2")
collection = client.get_or_create_collection(name="doctor_profiles_2")

existing_names = set()

PROMPT_TEMPLATE = """
Generate exactly 10 unique doctor profiles in valid JSON format.
Do not include any introductory or explanatory text—only return a valid JSON array.
Each profile should have the following fields:
- Name
- Specialization
- Sub-Specialization
- Years of Experience
- Hospital/Clinic Affiliation
- Certification
- Research
"""

def check_memory():
    mem = psutil.virtual_memory()
    if mem.percent > 95:
        print("High memory usage detected. Pausing for 30 seconds...")
        time.sleep(30)

def generate_profiles():
    payload = {
        "model": "llama3-70b-8192",
        "messages": [{"role": "user", "content": PROMPT_TEMPLATE}],
        "temperature": 0.7,
        "max_tokens": 2000
    }

    max_retries = 5
    base_delay = 10

    for attempt in range(max_retries):
        try:
            response = requests.post(url, headers=headers, json=payload)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.HTTPError as e:
            if response.status_code == 429:
                delay = base_delay * (2 ** attempt)
                delay += random.uniform(1, 5)
                print(f"Rate limit hit. Retrying in {delay:.2f} seconds...")
                time.sleep(delay)
            else:
                print(f"Request failed (attempt {attempt + 1}): {e}")
                time.sleep(30)

    print("Max retries reached. API is not responding.")
    return None

def extract_profiles(response):
    if not response or "choices" not in response:
        return []

    try:
        content = response["choices"][0]["message"]["content"].strip()

        json_start = content.find("[")
        json_end = content.rfind("]") + 1

        if json_start != -1 and json_end != -1:
            content = content[json_start:json_end]

        return json.loads(content)
    except json.JSONDecodeError:
        print("Error decoding JSON response. Raw response:")
        print(content)
        return []

def load_existing_names():
    global existing_names
    existing_names.clear()

    try:
        batch_size, offset = 100, 0
        while True:
            existing_docs = collection.get(include=["metadatas"], limit=batch_size, offset=offset)
            if not existing_docs or "metadatas" not in existing_docs or not existing_docs["metadatas"]:
                break

            for metadata in existing_docs["metadatas"]:
                if isinstance(metadata, dict) and "Name" in metadata:
                    existing_names.add(metadata["Name"])

            offset += batch_size
    except Exception as e:
        print(f"Error fetching ChromaDB metadata: {e}")

def save_profiles_to_chroma(profiles):
    load_existing_names()

    new_profiles = [p for p in profiles if p["Name"] not in existing_names]

    if new_profiles:
        try:
            doc_contents = [json.dumps(p) for p in new_profiles]
            metadata_list = new_profiles
            doc_ids = [p["Name"] for p in new_profiles]

            # Add documents in batch.
            collection.add(documents=doc_contents, metadatas=metadata_list, ids=doc_ids)
            print(f"{len(new_profiles)} profiles added to ChromaDB.")
        except Exception as e:
            print(f"Error adding profiles to ChromaDB: {e}")
    else:
        print("No new profiles to add.")

def count_profiles_in_chroma():
    try:
        stored_profiles = collection.get(include=["documents"])
        return len(stored_profiles["documents"]) if stored_profiles and "documents" in stored_profiles else 0
    except Exception as e:
        print(f"Error counting ChromaDB profiles: {e}")
        return 0

def main():
    total_profiles, batch_size, created_profiles = 500, 10, 0
    load_existing_names()

    while created_profiles < total_profiles:
        doctor_profiles = []

        while len(doctor_profiles) < batch_size:
            check_memory()

            response = generate_profiles()
            if response is None:
                print("API did not return a response. Retrying...")
                continue

            new_profiles = extract_profiles(response)
            for p in new_profiles:
                if p["Name"] not in existing_names:
                    doctor_profiles.append(p)
                    existing_names.add(p["Name"])

        if doctor_profiles:
            save_profiles_to_chroma(doctor_profiles)
            print(f"Batch Processed: {len(doctor_profiles)} profiles")
            print(f"Total Profiles in ChromaDB: {count_profiles_in_chroma()}")

            created_profiles += len(doctor_profiles)

        existing_names.clear()

        sleep_time = random.uniform(15, 30)
        print(f"Sleeping for {sleep_time:.2f} seconds...\n")
        time.sleep(sleep_time)

if __name__ == "__main__":
    main()
# Out:
# 10 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 10
# Sleeping for 22.03 seconds...
#
# 9 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 19
# Sleeping for 15.64 seconds...
#
# 6 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 25
# Sleeping for 27.83 seconds...
#
# 4 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 29
# Sleeping for 15.72 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 30
# Sleeping for 17.26 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 31
# Sleeping for 16.41 seconds...
#
# 2 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 33
# Sleeping for 28.06 seconds...
#
# 4 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 37
# Sleeping for 23.64 seconds...
#
# 4 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 41
# Sleeping for 20.88 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 42
# Sleeping for 25.37 seconds...
#
# No new profiles to add.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 42
# Sleeping for 23.65 seconds...
#
# No new profiles to add.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 42
# Sleeping for 20.23 seconds...
#
# 3 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 45
# Sleeping for 20.44 seconds...
#
# 7 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 52
# Sleeping for 26.27 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 53
# Sleeping for 15.24 seconds...
#
# 5 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 58
# Sleeping for 19.44 seconds...
#
# 4 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 62
# Sleeping for 28.84 seconds...
#
# 2 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 64
# Sleeping for 25.69 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 65
# Sleeping for 18.12 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 66
# Sleeping for 16.02 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 67
# Sleeping for 17.03 seconds...
#
# 6 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 73
# Sleeping for 28.21 seconds...
#
# 3 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 76
# Sleeping for 21.32 seconds...
#
# 2 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 78
# Sleeping for 27.80 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 79
# Sleeping for 23.55 seconds...
#
# 3 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 82
# Sleeping for 21.02 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 83
# Sleeping for 24.81 seconds...
#
# 3 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 86
# Sleeping for 27.70 seconds...
#
# 2 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 88
# Sleeping for 16.60 seconds...
#
# 2 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 90
# Sleeping for 27.90 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 91
# Sleeping for 29.96 seconds...
#
# 4 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 95
# Sleeping for 28.75 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 96
# Sleeping for 17.47 seconds...
#
# No new profiles to add.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 96
# Sleeping for 15.91 seconds...
#
# 1 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 97
# Sleeping for 19.73 seconds...
#
# 2 profiles added to ChromaDB.
# Batch Processed: 10 profiles
# Total Profiles in ChromaDB: 99
# Sleeping for 22.27 seconds...
